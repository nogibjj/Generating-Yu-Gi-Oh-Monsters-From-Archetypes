# %%
import pandas as pd

# %%
# !conda install pandas -y
# Out:
# Channels:
#  - defaults
#  - conda-forge
#  - nvidia
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/ygo
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.7           |  py312ha883a20_0         140 KB
#     numexpr-2.8.7              |  py312hf827012_0         149 KB
#     pandas-2.2.1               |  py312h526ad5a_0        15.4 MB
#     python-tzdata-2023.3       |     pyhd3eb1b0_0         140 KB
#     ------------------------------------------------------------
#                                            Total:        15.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   bottleneck         pkgs/main/linux-64::bottleneck-1.3.7-py312ha883a20_0
#   numexpr            pkgs/main/linux-64::numexpr-2.8.7-py312hf827012_0
#   pandas             pkgs/main/linux-64::pandas-2.2.1-py312h526ad5a_0
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages:
# pandas-2.2.1         | 15.4 MB   |                                       |   0%
# numexpr-2.8.7        | 149 KB    |                                       |   0%
#
# python-tzdata-2023.3 | 140 KB    |                                       |   0%
#
#
# pandas-2.2.1         | 15.4 MB   |                                       |   0%
# numexpr-2.8.7        | 149 KB    | ###9                                  |  11%
#
#
# bottleneck-1.3.7     | 140 KB    | ####2                                 |  11%
#
# pandas-2.2.1         | 15.4 MB   | ########3                             |  22%
# numexpr-2.8.7        | 149 KB    | ##################################### | 100%
# numexpr-2.8.7        | 149 KB    | ##################################### | 100%
#
#
# bottleneck-1.3.7     | 140 KB    | ##################################### | 100%
#
#
# pandas-2.2.1         | 15.4 MB   | ##################6                   |  50%
#
# python-tzdata-2023.3 | 140 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pandas as pd

# %%
df = pd.read_csv("/workspaces/Generating-Yu-Gi-Oh-Monsters-From-Archetypes/card_database.csv")

# %%
df["type"].unique()
# Out:
# array(['Spell Card', 'Flip Effect Monster', 'Normal Monster',
#        'Effect Monster', 'Trap Card', 'Union Effect Monster',
#        'Fusion Monster', 'Pendulum Effect Monster', 'Link Monster',
#        'XYZ Monster', 'Synchro Monster', 'Synchro Tuner Monster',
#        'Tuner Monster', 'Gemini Monster', 'Normal Tuner Monster',
#        'Spirit Monster', 'Ritual Effect Monster', 'Skill Card', 'Token',
#        'Pendulum Effect Fusion Monster', 'Toon Monster',
#        'Pendulum Normal Monster', 'Synchro Pendulum Effect Monster',
#        'Pendulum Tuner Effect Monster', 'XYZ Pendulum Effect Monster',
#        'Pendulum Effect Ritual Monster', 'Ritual Monster',
#        'Pendulum Flip Effect Monster'], dtype=object)

# %%
card = {"type": 'Synchro Pendulum Effect Monster'}

for type in set(card["type"].lower().split(" ")):

    if type in ["trap", "spell", "monster"]:

        print("OK")
# Out:
# OK

# %%
import pandas as pd

# %%
df = pd.read_csv("card_database.csv")

# %%
df.columns
# Out:
# Index(['id', 'name', 'type', 'desc', 'atk', 'def', 'level', 'race',
#        'attribute'],
#       dtype='object')

# %%
df["type"].unique()
# Out:
# array(['Spell Card', 'Flip Effect Monster', 'Normal Monster',
#        'Effect Monster', 'Trap Card', 'Union Effect Monster',
#        'Fusion Monster', 'Pendulum Effect Monster', 'Link Monster',
#        'XYZ Monster', 'Synchro Monster', 'Synchro Tuner Monster',
#        'Tuner Monster', 'Gemini Monster', 'Normal Tuner Monster',
#        'Spirit Monster', 'Ritual Effect Monster', 'Skill Card', 'Token',
#        'Pendulum Effect Fusion Monster', 'Toon Monster',
#        'Pendulum Normal Monster', 'Synchro Pendulum Effect Monster',
#        'Pendulum Tuner Effect Monster', 'XYZ Pendulum Effect Monster',
#        'Pendulum Effect Ritual Monster', 'Ritual Monster',
#        'Pendulum Flip Effect Monster'], dtype=object)

# %%
df["type"].value_counts(normalize=True)
# Out:
# type
# Effect Monster                     0.366422
# Spell Card                         0.179169
# Trap Card                          0.152190
# XYZ Monster                        0.044651
# Synchro Monster                    0.036661
# Tuner Monster                      0.036003
# Fusion Monster                     0.035627
# Link Monster                       0.033465
# Normal Monster                     0.032619
# Pendulum Effect Monster            0.025099
# Flip Effect Monster                0.012126
# Skill Card                         0.010058
# Ritual Effect Monster              0.009776
# Token                              0.006674
# Pendulum Normal Monster            0.003102
# Gemini Monster                     0.002914
# Union Effect Monster               0.002726
# Spirit Monster                     0.002444
# Synchro Tuner Monster              0.002162
# Toon Monster                       0.001598
# Pendulum Effect Fusion Monster     0.001034
# XYZ Pendulum Effect Monster        0.000940
# Normal Tuner Monster               0.000846
# Pendulum Tuner Effect Monster      0.000752
# Synchro Pendulum Effect Monster    0.000658
# Pendulum Effect Ritual Monster     0.000094
# Ritual Monster                     0.000094
# Pendulum Flip Effect Monster       0.000094
# Name: proportion, dtype: float64

# %%
def classifier_type(card):

    if "spell" in card.lower():
        return "spell"
    elif "trap" in card.lower():
        return "trap"
    elif "effect" in card.lower():
        return "effect monster"
    elif "monster" in card.lower():
        return "monster"
    else:
        return "unknown"

# %%
df["simplified_type"] = df["type"].apply(classifier_type)

# %%
df["simplified_type"].value_counts(normalize=True)
# Out:
# simplified_type
# effect monster    0.419722
# monster           0.232187
# spell             0.179169
# trap              0.152190
# unknown           0.016732
# Name: proportion, dtype: float64

# %%
import pandas as pd

# Suppose you have a DataFrame 'data' with columns 'stratum' and other columns you want to sample
# data = pd.read_csv('your_data.csv')

# Step 1: Group your data by the strata you want to sample from
groups = df.groupby('simplified_type')

# Step 2: Define a sampling function
def stratified_sample(group):
    return group.sample(frac=0.5, replace=True, random_state = 42)  # You can adjust the fraction and other parameters as needed

# Step 3: Apply the sampling function to each group
sampled_groups = groups.apply(stratified_sample)

# Step 4: Concatenate the sampled groups back together
sampled_data = sampled_groups.reset_index(drop=True)

# Now 'sampled_data' contains your stratified sample
# Out:
# /tmp/ipykernel_14309/2558895575.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_groups = groups.apply(stratified_sample)

# %%
sampled_data["simplified_type"].value_counts(normalize=True)
# Out:
# simplified_type
# effect monster    0.419628
# monster           0.232187
# spell             0.179169
# trap              0.152284
# unknown           0.016732
# Name: proportion, dtype: float64

# %%
sampled_data.shape
# Out:
# (5319, 10)

# %%
import pandas as pd

# %%
test_df = pd.read_csv("training_cards.csv")

# %%
def extract_image_id(image_path):
    """Extracts image file name from path"""
    return image_path.split("/")[-1]

# %%
test_df["image_path"]
# Out:
# 0     GAN_experiments/training_magician/30603688.jpg
# 1     GAN_experiments/training_magician/60709218.jpg
# 2     GAN_experiments/training_magician/15256925.jpg
# 3     GAN_experiments/training_magician/60948488.jpg
# 4     GAN_experiments/training_magician/54878729.jpg
#                            ...
# 57     GAN_experiments/training_magician/1784686.jpg
# 58    GAN_experiments/training_magician/63391643.jpg
# 59     GAN_experiments/training_magician/3078380.jpg
# 60    GAN_experiments/training_magician/21296502.jpg
# 61    GAN_experiments/training_magician/90960358.jpg
# Name: image_path, Length: 62, dtype: object

# %%
test_df["image_id"] = test_df["image_path"].apply(extract_image_id)
test_df['image_id']
# Out:
# 0     30603688.jpg
# 1     60709218.jpg
# 2     15256925.jpg
# 3     60948488.jpg
# 4     54878729.jpg
#           ...
# 57     1784686.jpg
# 58    63391643.jpg
# 59     3078380.jpg
# 60    21296502.jpg
# 61    90960358.jpg
# Name: image_id, Length: 62, dtype: object

# %%
allowed_images = set(test_df["image_id"].values)

# %%
allowed_images
# Out:
# {'101205006.jpg',
#  '101205069.jpg',
#  '111280.jpg',
#  '12266229.jpg',
#  '13722870.jpg',
#  '15256925.jpg',
#  '1784686.jpg',
#  '21296502.jpg',
#  '22634473.jpg',
#  '23020408.jpg',
#  '2314238.jpg',
#  '29436665.jpg',
#  '30603688.jpg',
#  '3078380.jpg',
#  '31699677.jpg',
#  '35191415.jpg',
#  '36996508.jpg',
#  '37818794.jpg',
#  '40737112.jpg',
#  '41721210.jpg',
#  '42006475.jpg',
#  '43892408.jpg',
#  '43892409.jpg',
#  '46986414.jpg',
#  '46986415.jpg',
#  '46986416.jpg',
#  '46986417.jpg',
#  '46986418.jpg',
#  '46986419.jpg',
#  '46986420.jpg',
#  '46986421.jpg',
#  '47222536.jpg',
#  '47963370.jpg',
#  '48680970.jpg',
#  '49702428.jpg',
#  '50237654.jpg',
#  '50725996.jpg',
#  '54878729.jpg',
#  '5829717.jpg',
#  '60709218.jpg',
#  '60948488.jpg',
#  '63391643.jpg',
#  '67227834.jpg',
#  '68334074.jpg',
#  '70168345.jpg',
#  '7084129.jpg',
#  '71696014.jpg',
#  '71703785.jpg',
#  '73452089.jpg',
#  '73752131.jpg',
#  '75190122.jpg',
#  '7922915.jpg',
#  '85059922.jpg',
#  '86509711.jpg',
#  '90960358.jpg',
#  '92377303.jpg',
#  '95477924.jpg',
#  '96239878.jpg',
#  '97631303.jpg',
#  '98502113.jpg',
#  '98502114.jpg',
#  '98502115.jpg'}

# %%
image_path = "training_images"

for image in os.listdir(image_path):
    if image not in allowed_images:
        os.remove(os.path.join(image_path, image))

# %%
os.listdir("/workspaces/Generating-Yu-Gi-Oh-Monsters-From-Archetypes/training_data_final/training_images")
# Out:
# ['86466163.jpg',
#  '69303178.jpg',
#  '31699677.jpg',
#  '95477924.jpg',
#  '8698851.jpg',
#  '67951831.jpg',
#  '36350300.jpg',
#  '53265336.jpg',
#  '40633297.jpg',
#  '28290705.jpg',
#  '60246171.jpg',
#  '90011152.jpg',
#  '46613515.jpg',
#  '24644634.jpg',
#  '14816857.jpg',
#  '79229522.jpg',
#  '38116136.jpg',
#  '90590304.jpg',
#  '22790910.jpg',
#  '17601919.jpg',
#  '14513273.jpg',
#  '20281581.jpg',
#  '6595475.jpg',
#  '52323207.jpg',
#  '89264428.jpg',
#  '74458486.jpg',
#  '74725513.jpg',
#  '41619242.jpg',
#  '93431862.jpg',
#  '41867019.jpg',
#  '29843092.jpg',
#  '31772684.jpg',
#  '66104644.jpg',
#  '98891840.jpg',
#  '42055234.jpg',
#  '23619206.jpg',
#  '98666339.jpg',
#  '75892194.jpg',
#  '98338152.jpg',
#  '91434208.jpg',
#  '93715853.jpg',
#  '20154092.jpg',
#  '11819473.jpg',
#  '80887952.jpg',
#  '59094601.jpg',
#  '39915560.jpg',
#  '70117791.jpg',
#  '38798785.jpg',
#  '8634636.jpg',
#  '34536276.jpg',
#  '46772449.jpg',
#  '55401221.jpg',
#  '61292243.jpg',
#  '25788011.jpg',
#  '85004150.jpg',
#  '94042337.jpg',
#  '22933016.jpg',
#  '49249907.jpg',
#  '94656263.jpg',
#  '17722185.jpg',
#  '60990740.jpg',
#  '36717258.jpg',
#  '77060848.jpg',
#  '92881099.jpg',
#  '15871676.jpg',
#  '70252926.jpg',
#  '83670388.jpg',
#  '71197066.jpg',
#  '58990362.jpg',
#  '38041941.jpg',
#  '26701483.jpg',
#  '43175858.jpg',
#  '75326861.jpg',
#  '37617348.jpg',
#  '25148255.jpg',
#  '79600447.jpg',
#  '35429292.jpg',
#  '22916281.jpg',
#  '56638325.jpg',
#  '87047161.jpg',
#  '24643836.jpg',
#  '73079836.jpg',
#  '75130221.jpg',
#  '66712905.jpg',
#  '98162021.jpg',
#  '48995978.jpg',
#  '52481437.jpg',
#  '2407147.jpg',
#  '78199891.jpg',
#  '57728571.jpg',
#  '61466310.jpg',
#  '31562086.jpg',
#  '12181376.jpg',
#  '15475415.jpg',
#  '82385847.jpg',
#  '75690317.jpg',
#  '79106360.jpg',
#  '53077251.jpg',
#  '87116928.jpg',
#  '7084129.jpg',
#  '50091196.jpg',
#  '65536818.jpg',
#  '52900001.jpg',
#  '93708824.jpg',
#  '91250514.jpg',
#  '52792430.jpg',
#  '45651298.jpg',
#  '21817254.jpg',
#  '26232916.jpg',
#  '54283059.jpg',
#  '55969226.jpg',
#  '60645181.jpg',
#  '72819261.jpg',
#  '23639291.jpg',
#  '27911549.jpg',
#  '26495087.jpg',
#  '30680659.jpg',
#  '66262416.jpg',
#  '43748308.jpg',
#  ...]

# %%
import os

# %%
len(os.listdir("/workspaces/Generating-Yu-Gi-Oh-Monsters-From-Archetypes/training_data_final/training_images"))
# Out:
# 5328

# %%
df2 = pd.read_csv("training_data_final/all_training_cards.csv")

# %%
df2.shape
# Out:
# (5328, 14)

# %%
len(df2["image_id"].unique())
# Out:
# 4160

# %%
new_image_path = "training_data_final/sampled_images"

print(len(os.listdir(new_image_path)))
# Out:
# 4160
